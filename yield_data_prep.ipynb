# %%
import pandas as pd
import numpy as np

# %%
d1=pd.read_csv("rice.csv")
d2=pd.read_csv("wheat.csv")
d3=pd.read_csv("cotton(lint).csv")
d4=pd.read_csv("sugarcane.csv")
d5=pd.read_csv("onion.csv")
d6=pd.read_csv("maize.csv")

# %%
d1=d1.dropna()
d2=d2.dropna()
d3=d3.dropna()
d4=d4.dropna()
d5=d5.dropna()
d6=d6.dropna()

# %%
d1['Yield']=(d1['Production']*1000)/d1['Area']
d2['Yield']=(d2['Production']*1000)/d2['Area']
d3['Yield']=(d3['Production']*1000)/d3['Area']
d4['Yield']=(d4['Production']*1000)/d4['Area']
d5['Yield']=(d5['Production']*1000)/d5['Area']
d6['Yield']=(d6['Production']*1000)/d6['Area']

# %%
def conditions(d):
    if (d['State_Name'] == 'Punjab'):
        return 649
    elif (d['State_Name'] == 'Andhra Pradesh'):
        return 1094
    elif (['State_Name'] == 'Uttar Pradesh'):
        return 1025
    elif (d['State_Name'] == 'Haryana'):
        return 617
    else:
        return 494
        


d1['Rainfall'] = d1.apply(conditions, axis=1)
d2['Rainfall'] = d2.apply(conditions, axis=1)
d3['Rainfall'] = d3.apply(conditions, axis=1)
d4['Rainfall'] = d4.apply(conditions, axis=1)
d5['Rainfall'] = d5.apply(conditions, axis=1)
d6['Rainfall'] = d6.apply(conditions, axis=1)

# %%
d1 = d1.drop("Unnamed: 0", axis=1)
d1 = d1.drop("State_Name", axis=1)
d1 = d1.drop("District_Name", axis=1)
d1 = d1.drop("S_No", axis=1)
d1 = d1.drop("pH", axis=1)
d1 = d1.drop("Moisture", axis=1)
d1 = d1.drop("Soil_Temp", axis=1)
d1 = d1.drop("Climate", axis=1)
d1 = d1.drop("Crop_Name", axis=1)
d1 = d1.drop("Season", axis=1)
d1 = d1.drop("Irrigation", axis=1)

d2 = d2.drop("Unnamed: 0", axis=1)
d2 = d2.drop("State_Name", axis=1)
d2 = d2.drop("District_Name", axis=1)
d2 = d2.drop("S_No", axis=1)
d2 = d2.drop("pH", axis=1)
d2 = d2.drop("Moisture", axis=1)
d2 = d2.drop("Soil_Temp", axis=1)
d2 = d2.drop("Climate", axis=1)
d2 = d2.drop("Crop_Name", axis=1)
d2 = d2.drop("Season", axis=1)
d2 = d2.drop("Irrigation", axis=1)

d3 = d3.drop("Unnamed: 0", axis=1)
d3 = d3.drop("State_Name", axis=1)
d3 = d3.drop("District_Name", axis=1)
d3 = d3.drop("S_No", axis=1)
d3 = d3.drop("pH", axis=1)
d3 = d3.drop("Moisture", axis=1)
d3 = d3.drop("Soil_Temp", axis=1)
d3 = d3.drop("Climate", axis=1)
d3 = d3.drop("Crop_Name", axis=1)
d3 = d3.drop("Season", axis=1)
d3 = d3.drop("Irrigation", axis=1)

d4 = d4.drop("Unnamed: 0", axis=1)
d4 = d4.drop("State_Name", axis=1)
d4 = d4.drop("District_Name", axis=1)
d4 = d4.drop("S_No", axis=1)
d4 = d4.drop("pH", axis=1)
d4 = d4.drop("Moisture", axis=1)
d4 = d4.drop("Soil_Temp", axis=1)
d4 = d4.drop("Climate", axis=1)
d4 = d4.drop("Crop_Name", axis=1)
d4 = d4.drop("Season", axis=1)
d4 = d4.drop("Irrigation", axis=1)

d5 = d5.drop("Unnamed: 0", axis=1)
d5 = d5.drop("State_Name", axis=1)
d5 = d5.drop("District_Name", axis=1)
d5 = d5.drop("S_No", axis=1)
d5 = d5.drop("pH", axis=1)
d5 = d5.drop("Moisture", axis=1)
d5 = d5.drop("Soil_Temp", axis=1)
d5 = d5.drop("Climate", axis=1)
d5 = d5.drop("Crop_Name", axis=1)
d5 = d5.drop("Season", axis=1)
d5 = d5.drop("Irrigation", axis=1)

d6 = d6.drop("Unnamed: 0", axis=1)
d6 = d6.drop("State_Name", axis=1)
d6 = d6.drop("District_Name", axis=1)
d6 = d6.drop("S_No", axis=1)
d6 = d6.drop("pH", axis=1)
d6 = d6.drop("Moisture", axis=1)
d6 = d6.drop("Soil_Temp", axis=1)
d6 = d6.drop("Climate", axis=1)
d6 = d6.drop("Crop_Name", axis=1)
d6 = d6.drop("Season", axis=1)
d6 = d6.drop("Irrigation", axis=1)

# %%
# Out:
#         Area  Production  UREA   DAP  MAP   MOP  NPK  TSP  Labour_hours  \
# 0     292000    879000.0  0.19  1.00    1  0.46  1.0    1         419.7
# 1     305000    878000.0  0.19  1.00    1  0.46  1.0    1         419.7
# 2     319000    991000.0  0.19  1.00    1  0.46  1.0    1         419.7
# 3     319000    972000.0  0.19  1.00    1  0.46  1.0    1         419.7
# 4     319000    958000.0  0.19  1.00    1  0.46  1.0    1         419.7
# 5     311000    879000.0  0.19  1.00    1  0.46  1.0    1         419.7
# 6     326000    872000.0  0.19  1.00    1  0.46  1.0    1         419.7
# 7     334000   1034000.0  0.19  1.00    1  0.46  1.0    1         419.7
# 8     345000   1003000.0  0.19  1.00    1  0.46  1.0    1         419.7
# 9     178000    538000.0  0.19  1.00    1  0.46  1.0    1         419.7
# 10    178000    546000.0  0.19  1.00    1  0.46  1.0    1         419.7
# 11    183000    532000.0  0.19  1.00    1  0.46  1.0    1         419.7
# ...

# %%
d1.to_csv("rice2.csv")
d2.to_csv("wheat2.csv")
d3.to_csv("cotton(lint)2.csv")
d4.to_csv("sugarcane2.csv")
d5.to_csv("onion2.csv")
d6.to_csv("maize2.csv")
