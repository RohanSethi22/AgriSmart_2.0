# %%
import pandas as pd

# %%
data=pd.read_csv("crop_production.csv")

# %%
data2=data.loc[data["Crop"] == "Rice"]

# %%
data2.insert(2, "Labour_hours",859.5)

# %%
data2.loc[data2['State_Name'] == "Andhra Pradesh", 'Labour_hours'] =824.4
data2.loc[data2['State_Name'] == "Assam", 'Labour_hours'] =699.6
data2.loc[data2['State_Name'] == "Bihar", 'Labour_hours'] =778.3
data2.loc[data2['State_Name'] == "Punjab", 'Labour_hours'] =419.7
data2.loc[data2['State_Name'] == "West Bengal", 'Labour_hours'] =1233.3
data2
sum_column = (data2["Production"]*1000)/ data2["Area"]
data2["yield"] = sum_column
data2
# Out:
# C:\Users\len0vo500\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# C:\Users\len0vo500\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                          State_Name             District_Name  Labour_hours  \
# 2       Andaman and Nicobar Islands                  NICOBARS         859.5
# 12      Andaman and Nicobar Islands                  NICOBARS         859.5
# ...

# %%
list(set(data2.District_Name))
# Out:
# ['BALODA BAZAR',
#  'EAST SIANG',
#  'SAWAI MADHOPUR',
#  'SOUTH ANDAMANS',
#  'NARAYANPUR',
#  'NUAPADA',
#  'AMRELI',
#  'KAMRUP',
#  'ARIYALUR',
#  'BANKURA',
#  'BANGALORE RURAL',
#  'JABALPUR',
#  'BAGHPAT',
#  'RATLAM',
#  'DHUBRI',
#  'DHALAI',
#  'CHITRAKOOT',
#  'GAUTAM BUDDHA NAGAR',
#  'NAWADA',
#  'BHOPAL',
#  'BARABANKI',
#  'NASHIK',
#  'KANNIYAKUMARI',
#  'NAMAKKAL',
#  'KOTTAYAM',
#  'MUKTSAR',
#  'SONBHADRA',
#  'HAILAKANDI',
#  'MUZAFFARPUR',
#  'GODDA',
#  'DODA',
#  'SINGRAULI',
#  'KANGRA',
#  'JALNA',
#  'BALANGIR',
#  'NAGPUR',
#  'SUNDARGARH',
#  'LALITPUR',
#  'SOUTH DISTRICT',
#  'MORENA',
#  'KANKER',
#  'MATHURA',
#  'DINDIGUL',
#  'KRISHNA',
#  'JHANSI',
#  'RAMANAGARA',
#  'S.A.S NAGAR',
#  'IMPHAL EAST',
#  'SAIHA',
#  'LONGDING',
#  'BHILWARA',
#  'GARIYABAND',
#  'ANANTAPUR',
#  'GORAKHPUR',
#  'GIRIDIH',
#  'PAURI GARHWAL',
#  'BARAMULLA',
#  'MON',
#  'KAUSHAMBI',
#  'UDUPI',
#  'REWA',
#  'SANT RAVIDAS NAGAR',
#  'SHAHDOL',
#  'KAPURTHALA',
# ...

# %%
data2.to_csv("rice.csv")

# %%
# !python -m pip install --upgrade pip
# Out:
# ...
#   Found existing installation: pip 19.0.3
#     Uninstalling pip-19.0.3:
#       Successfully uninstalled pip-19.0.3
# ...

# %%
# !pip3 install KMeans

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Importing the dataset
dataset = pd.read_csv('rice.csv')

#printing dataset
print(dataset)

X=dataset.values

#print(X)

# Applying k-means to the sample dataset
#k-means++’ : selects initial cluster centers for k-mean clustering in a smart way to speed up convergence. 
#Number of time the k-means algorithm will be run with different centroid seeds. The final results will be the best output of n_init consecutive runs in terms of inertia.
#Determines random number generation for centroid initialization.
kmeans = KMeans(n_clusters=3,init='k-means++',max_iter=300,n_init=10,random_state=0) 
#Compute cluster centers and predict cluster index for each sample.
y_kmeans = kmeans.fit_predict(X)


# Visualising the clusters
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0,1],c='red',label='A')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1,1],c='blue',label='B')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2,1],c='green',label='C')
plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],s=300,c='yellow',label='Centroids')
plt.title('Clusters')

plt.show()
# Out:
#        Unnamed: 0                   State_Name             District_Name  \
# 0               2  Andaman and Nicobar Islands                  NICOBARS
# 1              12  Andaman and Nicobar Islands                  NICOBARS
# 2              18  Andaman and Nicobar Islands                  NICOBARS
# 3              27  Andaman and Nicobar Islands                  NICOBARS
# 4              36  Andaman and Nicobar Islands                  NICOBARS
# 5              45  Andaman and Nicobar Islands                  NICOBARS
# 6              64  Andaman and Nicobar Islands                  NICOBARS
# 7              81  Andaman and Nicobar Islands  NORTH AND MIDDLE ANDAMAN
# 8              92  Andaman and Nicobar Islands  NORTH AND MIDDLE ANDAMAN
# 9              98  Andaman and Nicobar Islands  NORTH AND MIDDLE ANDAMAN
# 10            111  Andaman and Nicobar Islands  NORTH AND MIDDLE ANDAMAN
# 11            129  Andaman and Nicobar Islands            SOUTH ANDAMANS
# ...
