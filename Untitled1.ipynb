# %%
import pandas as pd

# %%
d=pd.read_csv("dataset_predict.csv")
d
# Out:
#         S_No State_Name District_Name       Season Irrigation    pH  Moisture  \
# 0          0     Punjab      AMRITSAR  Kharif             low  6.40        90
# 1          1     Punjab      AMRITSAR  Kharif             low  6.00        90
# 2          2     Punjab      AMRITSAR  Kharif          medium  6.25        80
# 3          3     Punjab      AMRITSAR  Kharif            high  6.00        60
# 4          4     Punjab      AMRITSAR  Kharif             low  6.50        90
# 5          5     Punjab      AMRITSAR  Kharif             low  6.00        90
# 6          6     Punjab      AMRITSAR  Rabi            medium  6.25        80
# 7          7     Punjab      AMRITSAR  Rabi              high  6.20        60
# 8          8     Punjab      AMRITSAR  Rabi              high  6.40        60
# 9          9     Punjab      AMRITSAR  Rabi            medium  6.00        80
# 10        10     Punjab      AMRITSAR  Whole Year      medium  6.00        80
# ...

# %%
list_of_crops=["Rice","Maize","Wheat","Sugarcane","Cotton(lint)","Onion"]
d2=d[d['Crop_Name'].isin(list_of_crops)]

# %%
d2.shape
# Out:
# (15842, 12)

# %%
d2.to_csv("dataset_predict_area.csv")
